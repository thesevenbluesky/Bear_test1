# %%
from pathlib import Path
print(list(Path('.').glob('*')))
# Out:
# [Path('.config'), Path('export.pkl'), Path('sample_data')]

# %%
from fastai.vision.all import *
import ipywidgets as widgets
from ipywidgets import VBox

# File upload widget
btn_upload = widgets.FileUpload()

# Output widget for displaying the uploaded image
out_pl = widgets.Output()

# Label for displaying the prediction
lbl_pred = widgets.Label()

# Button for running classification
btn_run = widgets.Button(description='Classify')

# Load the trained model
learn_inf = load_learner('export.pkl')

# Classification function
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred, pred_idx, probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# Combine widgets into an app
app = VBox([widgets.Label('Select your bear!'),
            btn_upload, btn_run, out_pl, lbl_pred])

# Display the app
display(app)
# Out:
# VBox(children=(Label(value='Select your bear!'), FileUpload(value={}, description='Upload'), Button(descriptio…
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
